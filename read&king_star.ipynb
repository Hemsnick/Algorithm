# %%
# combine dataframe from folder
from functools import reduce
import pandas as pd
import os
filelist=os.listdir('king_book_commit')
df_group=map(lambda x:pd.read_json(f'./king_book_commit/{x}'),filelist)
king_df=reduce(lambda x, y:pd.concat([x,y],ignore_index=True), df_group)
king_df.head()
# Out:
#              BOOKNAME           ISBN       USER  \
# 0  散播閱讀火苗的人：臺灣圖書教師的故事  9789864712458    hw*der*
# 1               教育社會學  9789868173477    ge**rlo
# 2              教育創造未來  9789862169872    wu**an0
# 3              教育哲學導論                   ge**rlo
# 4               李戡戡亂記  9789575101312  ca****103
#
#                                              CONTENT
# 0  推薦文說，當圖書館老師，除了可名正言順讀書，還推動閱讀，引領孩子進入閱讀世界，更是功德無量。...
# 1  教育社會學是一門以教育行動的學門，教育的結構、制度等等的研究，教育的變遷與生活、理論與實際都...
# 2  ※※※評價：好書。※此書由洪蘭教授在遠見雜誌專欄撰寫的文章串輯而成。許多的真知灼見打開我的視...
# 3  教育哲學是教育的形上學、知識論與價值論。從傳統的哲學派別討論教育、當代哲學與教育理論都是有關...
# 4  年紀輕，就器小易盈嗎？李戡先生點出教育者除非從基本面改頭換面要不然學生絕無大頭腦大智慧的前途...

# %%
# 同userw同ISBN 合併
king_df=king_df.drop_duplicates(subset=['ISBN','USER'],ignore_index=True)
king_df.head()
# Out:
#              BOOKNAME           ISBN       USER  \
# 0  散播閱讀火苗的人：臺灣圖書教師的故事  9789864712458    hw*der*
# 1               教育社會學  9789868173477    ge**rlo
# 2              教育創造未來  9789862169872    wu**an0
# 3              教育哲學導論                   ge**rlo
# 4               李戡戡亂記  9789575101312  ca****103
#
#                                              CONTENT
# 0  推薦文說，當圖書館老師，除了可名正言順讀書，還推動閱讀，引領孩子進入閱讀世界，更是功德無量。...
# 1  教育社會學是一門以教育行動的學門，教育的結構、制度等等的研究，教育的變遷與生活、理論與實際都...
# 2  ※※※評價：好書。※此書由洪蘭教授在遠見雜誌專欄撰寫的文章串輯而成。許多的真知灼見打開我的視...
# 3  教育哲學是教育的形上學、知識論與價值論。從傳統的哲學派別討論教育、當代哲學與教育理論都是有關...
# 4  年紀輕，就器小易盈嗎？李戡先生點出教育者除非從基本面改頭換面要不然學生絕無大頭腦大智慧的前途...

# %%
# 刪除 ISBN 是空值的
king_df=king_df.drop(king_df[king_df["ISBN"]==""].index)
king_df.head()
# Out:
#                         BOOKNAME           ISBN           USER  \
# 0             散播閱讀火苗的人：臺灣圖書教師的故事  9789864712458        hw*der*
# 1                          教育社會學  9789868173477        ge**rlo
# 2                         教育創造未來  9789862169872        wu**an0
# 4                          李戡戡亂記  9789575101312      ca****103
# 5                  愛的激勵：成就孩子的大未來  9789571361642        av**214
# ...                          ...            ...            ...
# 17565          國中英聽實力養成保證班（附MP3）  9789866371639        l**ac**
# 17566  朗文國中英語文法練習會考限量套書(基礎篇+進階篇)  9789160013921  69********661
# 17567      榜首這樣Ｋ基測：數學科25個奪分題型大解析  9789861362243      sa****619
# 17568            考前10分鐘地球科學一本就夠！  9789865845490       ho***926
# 17569               字音字形每天練習（全冊）  4712839705556      sa****619
#
#                                                  CONTENT
# 0      推薦文說，當圖書館老師，除了可名正言順讀書，還推動閱讀，引領孩子進入閱讀世界，更是功德無量。...
# 1      教育社會學是一門以教育行動的學門，教育的結構、制度等等的研究，教育的變遷與生活、理論與實際都...
# 2      ※※※評價：好書。※此書由洪蘭教授在遠見雜誌專欄撰寫的文章串輯而成。許多的真知灼見打開我的視...
# 4      年紀輕，就器小易盈嗎？李戡先生點出教育者除非從基本面改頭換面要不然學生絕無大頭腦大智慧的前途...
# 5      我是新手媽媽，從他出生起我就不斷摸索如何與他相處。 現在他漸漸大了，也發現他開始有自己的想法...
# ...                                                  ...
# 17565  發現這是一本從基礎發音與辨音的基礎書本,適合從頭開始學英語的每一個人,不只是國中生!!值得推...
# 17566  很適合國二生開始做會考的總複習，裡面的文法練習題可以幫助學生對文法的運用更熟悉，很推薦國中生...
# 17567  本身有接家教，所以小朋友要拼基測數學時我有買一本給他寫，題庫量很夠，排版也很有條理，學生寫起...
# 17568  一開始我覺得感覺好像還滿有用的,但對考試實用性並不高,若不想因為本書搞到分數考差,那就來看看...
# 17569  這幾天和成立的讀書會成員們討論考試用書，大家都很喜歡這一本，所以一次就訂了七本，因為內容剛好...
#
# [17543 rows x 4 columns]

# %%
# df.to_json('king_commit.json',orient='records',lines=True,force_ascii=False)

# %%
# from pymongo import MongoClient
# import json

# client = MongoClient(host='10.2.14.10',port=27017)
# db = client.userstar
# coll = db.king_commit

# with open ('king_commit.json','r',encoding='utf-8') as f:
#     for a in f:
#         ccc=json.loads(a)
#         coll.insert([ccc])

# %%
# 讀出 readmoo 有評分的檔案
import pymongo
import pandas as pd
from pymongo import MongoClient
MONGO_HOST = '10.2.14.10'
MONGO_DB = 'userstar'
MONGO_COLLETION = 'userstar'

def connect_mongo():  #連線資料庫
    global collection
    client = MongoClient(MONGO_HOST, 27017)
    db = client[MONGO_DB]
    collection = db[MONGO_COLLETION]

connect_mongo()  #呼叫連線資料庫函式
cursor = collection.find()  #依query查詢資料
userstar_df=  pd.DataFrame(list(cursor))  #轉換成DataFrame
del userstar_df['_id']
userstar_df['ISBN'] = userstar_df['ISBN'].astype('str')  # 確認 ISBN 為字串
userstar_df.head()
# Out:
#             ISBN                                        BOOKNAME        USER  \
# 0  9789865683498  「氣內臟」自癒按摩法：每天按摩脾．肝．腎30秒，美肌、消除便秘、好眠、減肥，天天都有好氣色！          啟迪
# 1  9789575036942                                   唐鳳：我所看待的自由與未來  Miley Guan
# 2  9789865241810                                     老夫老妻重返青春（1）          蘇蘇
# 3  9789864779079                                        祕密瑜伽士的日常  kbboss7416
# 4  9789571068121                                        花開千年（01）       Annie
#
#                                              CONTENT USERSTAR
# 0  深入淺出，圖片清晰介唔按壓身體及伸展。\n按照個人體質、情志、節氣等，以吃，嗅香芬、調息、伸...      5.0
# 1  一開始是對唐鳳好奇，想更了解她，讀完之後真正體認到她是個傳奇人物，同時她的家庭給了她很大的自...      5.0
# 2                                看了很暖心的漫畫，會覺得要好好過每一天      0.0
# 3                                   直指心性的好書，書中道理發人省思      5.0
# 4  好唯美的畫風。喜歡故事開頭引用的一段《佛經》：「彼岸花，開一千年，落一千年，花葉永不想見。情...      5.0

# %%
# 使用 snownlp文本
from snownlp import SnowNLP,sentiment
sentiment.train(r'C:\Users\Tibame\Desktop\readmoo\neg1.txt', r'C:\Users\Tibame\Desktop\readmoo\pos1.txt')

# %%
# 挑出 ISBN 為 0
readroom_df=userstar_df[userstar_df["USERSTAR"]==0]
readroom_df=readroom_df.dropna()

# %%
# 挑出 ISBN 不為 0
readroom_df1=userstar_df[userstar_df["USERSTAR"]!=0]
readroom_df1=readroom_df1.dropna()

# %%
# snownlp 給分規則
def snow_result(CONTENT):
    s = SnowNLP(CONTENT)
    if s.sentiments >= 0.8:
        return float(5.0)
    elif s.sentiments >= 0.6:
        return float(4.0)
    elif s.sentiments >= 0.3:
        return float(3.0)
    else:
        return float(1.0)

# %%
# readoom給分
readroom_df['USERSTAR'] = readroom_df.CONTENT.apply(snow_result)
readroom_df
# Out:
#                 ISBN        BOOKNAME           USER  \
# 2      9789865241810     老夫老妻重返青春（1）             蘇蘇
# 12     9789869662451            偽婚世代            豬血糕
# 26     9789863449041          掌心裡的京都        fangyin
# 31     4717702071059  重力小丑 (2010年新版)         summer
# 65     9789573337010         月亮前方三公里  Otter4018 三口竹
# ...              ...             ...            ...
# 99464  9789868658103        裝幀時代(平裝)          hou26
# 99474  9787100075046          大革命写真画          hou26
# 99476  9787506011341              冰魂          hou26
# 99490  9789866954184            重力小丑   Murasakitobi
# 99529  9789866954702            平面犬。   Murasakitobi
#
#                                                  CONTENT  USERSTAR
# 2                                    看了很暖心的漫畫，會覺得要好好過每一天         5
# 12     四個女高中同學，四種個性，四種不一樣的婚姻愛情，卻在不同的際遇裡分別自我成長。非常好看的小說...         5
# 26     有一點京都味，是京都人才寫得出的小說。\n\n小說的開場是被派去買菜的小妹經過北山（府立）植...         5
# 31     這本書是2010年新版，又經過電子化，錯字還是多得很誇張，讓人懷疑譯者的專業素養和編輯是否不...         5
# 65     月亮前方三公里 – 不管哪一面都是真實的你\nBy伊與原新\n\n這是一本短篇小說集\n第一...         5
# ...                                                  ...       ...
# 99464        這是本文字未加修飾、瑣碎不易讀的書，但肯定作者的用心。期待作者更有系統的裝幀論述出版。         5
# 99474             圖比愛問上的原書掃描版還不清楚，印刷質量真是……序還把高崙寫成高倉了（汗）！         1
# 99476  最早是在《讀者文摘》中文版1998年一月號讀到極為濃縮的摘要，當時印象非常深刻。雖然回憶錄不...         5
# 99490  伊坂的書我只看過死神精確度跟OH!Farther，就目前的閱讀經驗來說，我發現伊坂的敘事口氣...         5
# 99529  之前看過乙一的短篇小說集<>,當時覺得非常的好看,這次再看了這本<<平面犬>>,雖然感覺有點...         5
#
# [6324 rows x 5 columns]

# %%
# king給分
king_df['USERSTAR'] = king_df.CONTENT.apply(snow_result)
king_df
# Out:
#                         BOOKNAME           ISBN           USER  \
# 0             散播閱讀火苗的人：臺灣圖書教師的故事  9789864712458        hw*der*
# 1                          教育社會學  9789868173477        ge**rlo
# 2                         教育創造未來  9789862169872        wu**an0
# 4                          李戡戡亂記  9789575101312      ca****103
# 5                  愛的激勵：成就孩子的大未來  9789571361642        av**214
# ...                          ...            ...            ...
# 17565          國中英聽實力養成保證班（附MP3）  9789866371639        l**ac**
# 17566  朗文國中英語文法練習會考限量套書(基礎篇+進階篇)  9789160013921  69********661
# 17567      榜首這樣Ｋ基測：數學科25個奪分題型大解析  9789861362243      sa****619
# 17568            考前10分鐘地球科學一本就夠！  9789865845490       ho***926
# 17569               字音字形每天練習（全冊）  4712839705556      sa****619
#
#                                                  CONTENT  USERSTAR
# 0      推薦文說，當圖書館老師，除了可名正言順讀書，還推動閱讀，引領孩子進入閱讀世界，更是功德無量。...         5
# 1      教育社會學是一門以教育行動的學門，教育的結構、制度等等的研究，教育的變遷與生活、理論與實際都...         5
# 2      ※※※評價：好書。※此書由洪蘭教授在遠見雜誌專欄撰寫的文章串輯而成。許多的真知灼見打開我的視...         5
# 4      年紀輕，就器小易盈嗎？李戡先生點出教育者除非從基本面改頭換面要不然學生絕無大頭腦大智慧的前途...         5
# 5      我是新手媽媽，從他出生起我就不斷摸索如何與他相處。 現在他漸漸大了，也發現他開始有自己的想法...         5
# ...                                                  ...       ...
# 17565  發現這是一本從基礎發音與辨音的基礎書本,適合從頭開始學英語的每一個人,不只是國中生!!值得推...         5
# 17566  很適合國二生開始做會考的總複習，裡面的文法練習題可以幫助學生對文法的運用更熟悉，很推薦國中生...         5
# 17567  本身有接家教，所以小朋友要拼基測數學時我有買一本給他寫，題庫量很夠，排版也很有條理，學生寫起...         5
# 17568  一開始我覺得感覺好像還滿有用的,但對考試實用性並不高,若不想因為本書搞到分數考差,那就來看看...         5
# 17569  這幾天和成立的讀書會成員們討論考試用書，大家都很喜歡這一本，所以一次就訂了七本，因為內容剛好...         5
#
# [17543 rows x 5 columns]

# %%
# 合併
userstar_df = pd.concat([readroom_df,readroom_df1],axis=0)
userstar_df
# Out:
#                  ISBN                     BOOKNAME           USER  \
# 2       9789865241810                  老夫老妻重返青春（1）             蘇蘇
# 12      9789869662451                         偽婚世代            豬血糕
# 26      9789863449041                       掌心裡的京都        fangyin
# 31      4717702071059               重力小丑 (2010年新版)         summer
# 65      9789573337010                      月亮前方三公里  Otter4018 三口竹
# ...               ...                          ...            ...
# 100787  9789865248611          我轉生為解決劇情需求的公主角色 (2)            密碼子
# 100788  9789576584428  我拿青春換明天：八大行業職場說明書，慾海求生的人物群像            一起飛
# 100789  9789864894253               午夜圖書館【經典奇幻設計款】    Candy Cheng
# 100790  9789869572460               遲來的羽翼（古籍研究社系列）        翎雪Rinn.
# 100791              0                    非婚家族(04)完      從羅曼史畢業的秀蓮
#
#                                                   CONTENT USERSTAR
# 2                                     看了很暖心的漫畫，會覺得要好好過每一天        5
# 12      四個女高中同學，四種個性，四種不一樣的婚姻愛情，卻在不同的際遇裡分別自我成長。非常好看的小說...        5
# 26      有一點京都味，是京都人才寫得出的小說。\n\n小說的開場是被派去買菜的小妹經過北山（府立）植...        5
# 31      這本書是2010年新版，又經過電子化，錯字還是多得很誇張，讓人懷疑譯者的專業素養和編輯是否不...        5
# 65      月亮前方三公里 – 不管哪一面都是真實的你\nBy伊與原新\n\n這是一本短篇小說集\n第一...        5
# ...                                                   ...      ...
# 100787                                         意外有趣！期待第三本        5
# 100788                          雖然有抄襲爭議，但不可否認這本書的內容還蠻有趣的。        4
# 100789  世界沒有完美的人生，只有換轉另一個角度去看。\n『不論在哪個人生，我們都一樣完整，活得一樣精...        5
# 100790  一口氣看完古籍研究社系列，很喜歡這種日常推理的故事，悠閒中也有一點緊湊，中間夾雜了愛情元素，...        5
# 100791                        很好看，家庭的形式可以很多元，只要彼此真心相愛與關心。        5
#
# [100521 rows x 5 columns]

# %%
# 合併
df = pd.concat([userstar_df,king_df],axis=0)
df
# Out:
#                 ISBN                   BOOKNAME           USER  \
# 2      9789865241810                老夫老妻重返青春（1）             蘇蘇
# 12     9789869662451                       偽婚世代            豬血糕
# 26     9789863449041                     掌心裡的京都        fangyin
# 31     4717702071059             重力小丑 (2010年新版)         summer
# 65     9789573337010                    月亮前方三公里  Otter4018 三口竹
# ...              ...                        ...            ...
# 17565  9789866371639          國中英聽實力養成保證班（附MP3）        l**ac**
# 17566  9789160013921  朗文國中英語文法練習會考限量套書(基礎篇+進階篇)  69********661
# 17567  9789861362243      榜首這樣Ｋ基測：數學科25個奪分題型大解析      sa****619
# 17568  9789865845490            考前10分鐘地球科學一本就夠！       ho***926
# 17569  4712839705556               字音字形每天練習（全冊）      sa****619
#
#                                                  CONTENT USERSTAR
# 2                                    看了很暖心的漫畫，會覺得要好好過每一天        5
# 12     四個女高中同學，四種個性，四種不一樣的婚姻愛情，卻在不同的際遇裡分別自我成長。非常好看的小說...        5
# 26     有一點京都味，是京都人才寫得出的小說。\n\n小說的開場是被派去買菜的小妹經過北山（府立）植...        5
# 31     這本書是2010年新版，又經過電子化，錯字還是多得很誇張，讓人懷疑譯者的專業素養和編輯是否不...        5
# 65     月亮前方三公里 – 不管哪一面都是真實的你\nBy伊與原新\n\n這是一本短篇小說集\n第一...        5
# ...                                                  ...      ...
# 17565  發現這是一本從基礎發音與辨音的基礎書本,適合從頭開始學英語的每一個人,不只是國中生!!值得推...        5
# 17566  很適合國二生開始做會考的總複習，裡面的文法練習題可以幫助學生對文法的運用更熟悉，很推薦國中生...        5
# 17567  本身有接家教，所以小朋友要拼基測數學時我有買一本給他寫，題庫量很夠，排版也很有條理，學生寫起...        5
# 17568  一開始我覺得感覺好像還滿有用的,但對考試實用性並不高,若不想因為本書搞到分數考差,那就來看看...        5
# 17569  這幾天和成立的讀書會成員們討論考試用書，大家都很喜歡這一本，所以一次就訂了七本，因為內容剛好...        5
#
# [118064 rows x 5 columns]

# %%
# 讀取金石堂所有書本
MONGO_HOST = '10.2.14.10'
MONGO_DB = 'kingstone'
MONGO_COLLETION = 'clean_data'

def connect_mongo():  #連線資料庫
    global collection
    client = MongoClient(MONGO_HOST, 27017)
    db = client[MONGO_DB]
    collection = db[MONGO_COLLETION]

connect_mongo()  #呼叫連線資料庫函式
cursor = collection.find()  #依query查詢資料
book_df=  pd.DataFrame(list(cursor))  #轉換成DataFrame
del book_df['_id']
book_df['ISBN'] = book_df['ISBN'].astype('str')  # 確認 ISBN 為字串
book_df.head()
# Out:
#                                              書名           ISBN  \
# 0  瞄過一眼就忘不了的世界史：高中老師╳神級YouTuber 2，000萬次點閱的超人氣課程  9789863844433
# 1                大戰略：耶魯大學長紅20年大師課程，從歷史提煉的領導決策心法  9789570856712
# 2                                 歷史學的探究與實作操作手冊  9789570533446
# 3                  忘了自己是動物的人類：重思生命起源的歷史與身而為人的意義  9789864779376
# 4                       西方憑什麼：五萬年人類大歷史，破解中國落後之謎  9789868271272
#
#                                                words
# 0  瞄過一眼忘不世界史高中老師神級 萬次點閱超人氣課程高中老師神級最強圖像記憶法萬次點閱超人氣課...
# 1  大戰略耶魯大學長紅年大師課程從歷史提煉領導決策心法金石堂強力推薦書 耶魯大學長紅年戰略大師課...
# 2  歷史學探究實作操作手冊課綱歷史科目探究實作課程規劃設計參考指南一次解決 主題設定課程活動參考...
# 3  忘自己動物人類重思生命起源歷史身為人意義最優美生命起源敘事重思人類身為動物美麗哀愁英美加德義...
# 4  西方憑什麼五萬年人類大歷史破解中國落後之謎 美國筆會書獎德國國際財經書獎 美國英國中國德國暢...

# %%
# 有書評的書  和金石堂的書 取交集
df1=pd.merge(book_df,df,on=['ISBN'],how='inner')
del df1['BOOKNAME']
df1.head()
# Out:
#                                              書名           ISBN  \
# 0  瞄過一眼就忘不了的世界史：高中老師╳神級YouTuber 2，000萬次點閱的超人氣課程  9789863844433
# 1                大戰略：耶魯大學長紅20年大師課程，從歷史提煉的領導決策心法  9789570856712
# 2                大戰略：耶魯大學長紅20年大師課程，從歷史提煉的領導決策心法  9789570856712
# 3                       西方憑什麼：五萬年人類大歷史，破解中國落後之謎  9789868271272
# 4                       西方憑什麼：五萬年人類大歷史，破解中國落後之謎  9789868271272
#
#                                                words           USER  \
# 0  瞄過一眼忘不世界史高中老師神級 萬次點閱超人氣課程高中老師神級最強圖像記憶法萬次點閱超人氣課...        Frankie
# 1  大戰略耶魯大學長紅年大師課程從歷史提煉領導決策心法金石堂強力推薦書 耶魯大學長紅年戰略大師課...  luckylife8957
# 2  大戰略耶魯大學長紅年大師課程從歷史提煉領導決策心法金石堂強力推薦書 耶魯大學長紅年戰略大師課...        suliwen
# 3  西方憑什麼五萬年人類大歷史破解中國落後之謎 美國筆會書獎德國國際財經書獎 美國英國中國德國暢...   p26842082001
# 4  西方憑什麼五萬年人類大歷史破解中國落後之謎 美國筆會書獎德國國際財經書獎 美國英國中國德國暢...     rex.mcchiu
#
#                                              CONTENT USERSTAR
# 0  書中先按時期分類，將世界史分開前、中、後三個時期，再將前期世界史按地區分類，令錯綜複雜的大混...      5.0
# 1  這本書花了一點時間才看完，雖然厚度頗高，讀起來卻是趣味十足。\n從一個寓言故事開始破題，然後...        5
# 2                  列舉了貫穿古今的戰役歷史，不懂戰略的人來看也是很好看的歷史故事集。      5.0
# 3                                    古早決定論 vs. 一時碰巧論        3
# 4             東西方比對發展軌跡的論述，清晰、具說服力時之所需支撐社會發展方向+地理決定論      5.0
